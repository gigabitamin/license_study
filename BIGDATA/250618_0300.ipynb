# %% [markdown]
# # 빅분기 실기 유형 1 연습

# %%
# 여러줄 출력 가능
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
# df.info()

# %%
# 1. 인기동영상 제작횟수가 많은 채널 상위 10개
top10 = df['channelTitle'].value_counts(ascending=False).head(10).reset_index()['channelTitle']
print(top10)
# Out:
# 0                       짤툰
# 1                      파뿌리
# 2                    SPOTV
# 3          런닝맨 - 스브스 공식 채널
# 4    엠뚜루마뚜루 : MBC 공식 종합 채널
# 5                      장삐쭈
# 6                BANGTANTV
# 7                   채널 십오야
# 8                      이과장
# 9                      총몇명
# Name: channelTitle, dtype: object

# %%
answer = list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique())
print(answer)
# Out:
# ['장삐쭈', '총몇명', '파뿌리', '짤툰', '런닝맨 - 스브스 공식 채널', '엠뚜루마뚜루 : MBC 공식 종합 채널', 'SPOTV', '채널 십오야', '이과장', 'BANGTANTV']

# %%
top10 = df['channelTitle'].value_counts(ascending=False).head(10)
print(top10)
top10 = df['channelId'].value_counts(ascending=False).head(10)
print(top10)
# Out:
# channelTitle
# 짤툰                       372
# 파뿌리                      318
# SPOTV                    318
# 런닝맨 - 스브스 공식 채널          313
# 엠뚜루마뚜루 : MBC 공식 종합 채널    293
# 장삐쭈                      283
# BANGTANTV                275
# 채널 십오야                   274
# 이과장                      258
# 총몇명                      255
# Name: count, dtype: int64
# channelId
# UCszFjh7CEfwDb7UUGb4RzCQ    372
# UClzB2iZ5jPoTNz0S-QU6Wiw    318
# UCtm_QoN2SIxwCE-59shX7Qg    318
# UCaKod3X1Tn4c7Ci0iUKcvzQ    313
# UCiwQRG2sCcfjKkgxMEdJGPg    293
# UChbE5OZQ6dRHECsX0tEPEZQ    283
# UCLkAepWjdylmXSltofFvsYQ    275
# UCQ2O-iftmnlfrBuNsUUTofQ    274
# UCtfriFvIe5gIe8wRWb8UTMg    258
# UCRuSxVu4iqTK5kCh90ntAgA    255
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#                                               title             channelTitle  \
# 0                                         [신병] 물자창고                      장삐쭈
# 1  RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01

# %%
df_u1 = df[['channelTitle', 'channelId']].drop_duplicates().channelId.value_counts()
df_u2 = df[['channelTitle', 'channelId']].drop_duplicates().channelTitle.value_counts()
df_u3 = df[['channelTitle', 'channelId']].channelTitle.value_counts()
df_u1
df_u2
df_u3
# Out:
# channelId
# UCtQYhzJWFai1y30UIA3uwYQ    3
# UC98TOxKQk4aLcx0EjIK0LkQ    3
# UC4nEQI74rZkFKlUSwi0ur4A    2
# UCn64fSqF2l4rkkjtQUpku2A    2
# UCjO3ji06DxmTM1RrzLVwmkA    2
#                            ..
# UCuZu8NrpBG4WPXRi-hPBl-A    1
# UCDrAR1OWC2MD4s0JLetN0MA    1
# UCx2MVBsdTJ_sv0LiUpSQU2Q    1
# UCu2R3TCLSxYV8pRyBGNOh2g    1
# UCRCK5FCJtomQT3b88jXI_DA    1
# Name: count, Length: 1770, dtype: int64
# channelTitle
# Various Artists - Topic    11
# THE BOYZ                    2
# 운동준독                        1
# channel CKOONY              1
# 쫀득TV                        1
#                            ..
# 방송통신대학교&방송대학TV              1
# KBS 같이삽시다                   1
# 달리 [SBS 교양 공식채널]            1
# (MUTUBE)와꾸대장봉준              1
# 한국닌텐도 공식 채널                 1
# Name: count, Length: 1832, dtype: int64
# channelTitle
# 짤툰                       372
# 파뿌리                      318
# SPOTV                    318
# 런닝맨 - 스브스 공식 채널          313
# 엠뚜루마뚜루 : MBC 공식 종합 채널    293
# ...

# %%
df[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.drop_duplicates()
df[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique()
df[df.channelId.isin(df.channelId.value_counts().head(10).index)]['channelTitle'].drop_duplicates()
# Out:
# 0                         장삐쭈
# 27                        총몇명
# 32                        파뿌리
# 76                         짤툰
# 100           런닝맨 - 스브스 공식 채널
# 125     엠뚜루마뚜루 : MBC 공식 종합 채널
# 192                     SPOTV
# 214                    채널 십오야
# 1219                      이과장
# 5204                BANGTANTV
# Name: channelTitle, dtype: object
# array(['장삐쭈', '총몇명', '파뿌리', '짤툰', '런닝맨 - 스브스 공식 채널',
#        '엠뚜루마뚜루 : MBC 공식 종합 채널', 'SPOTV', '채널 십오야', '이과장', 'BANGTANTV'],
#       dtype=object)
# 0                         장삐쭈
# 27                        총몇명
# 32                        파뿌리
# 76                         짤툰
# 100           런닝맨 - 스브스 공식 채널
# 125     엠뚜루마뚜루 : MBC 공식 종합 채널
# 192                     SPOTV
# 214                    채널 십오야
# 1219                      이과장
# 5204                BANGTANTV
# Name: channelTitle, dtype: object

# %%
# 2. 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df[df['dislikes'] > df['likes']]['channelTitle'].value_counts()
# Out:
# channelTitle
# 양팡 YangPang                   44
# Gen.G esports                 17
# (MUTUBE)와꾸대장봉준                11
# 하얀트리HayanTree                 10
# 철구형 (CHULTUBE)                10
# 오메킴TV                         10
# 핫도그TV                          8
# 왜냐맨하우스                         8
# 육지담                            7
# MapleStory_KR                  7
# ROAD FIGHTING CHAMPIONSHIP     7
# ASMR 애정TV                      2
# 사나이 김기훈                        1
# 나혼자산다 STUDIO                   1
# Name: count, dtype: int64

# %%
df['dislikes'] > df['likes']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60394    False
# 60395    False
# 60396    False
# 60397    False
# 60398    False
# Length: 60399, dtype: bool

# %%
df[df['channelId'].isin(df[df['dislikes'] > df['likes']]['channelId'].value_counts().index)].channelTitle.unique()
# Out:
# array(['나혼자산다 STUDIO', '사나이 김기훈', '핫도그TV', 'ASMR 애정TV', '하얀트리HayanTree',
#        '(MUTUBE)와꾸대장봉준', '양팡 YangPang', '철구형 (CHULTUBE)', '왜냐맨하우스',
#        '오메킴TV', '육지담', 'MapleStory_KR', 'ROAD FIGHTING CHAMPIONSHIP',
#        'Gen.G esports'], dtype=object)

# %%
# 3. 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라
df[['channelTitle', 'channelId']].drop_duplicates().channelId.value_counts()
# Out:
# channelId
# UCtQYhzJWFai1y30UIA3uwYQ    3
# UC98TOxKQk4aLcx0EjIK0LkQ    3
# UC4nEQI74rZkFKlUSwi0ur4A    2
# UCn64fSqF2l4rkkjtQUpku2A    2
# UCjO3ji06DxmTM1RrzLVwmkA    2
#                            ..
# UCuZu8NrpBG4WPXRi-hPBl-A    1
# UCDrAR1OWC2MD4s0JLetN0MA    1
# UCx2MVBsdTJ_sv0LiUpSQU2Q    1
# UCu2R3TCLSxYV8pRyBGNOh2g    1
# UCRCK5FCJtomQT3b88jXI_DA    1
# Name: count, Length: 1770, dtype: int64

# %%
n_changed = df[['channelId', 'channelTitle']].drop_duplicates().groupby('channelId').size()
n_changed = (n_changed > 1).sum()
print(f"채널명을 바꾼 채널의 수: {n_changed}")
# Out:
# 채널명을 바꾼 채널의 수: 71

# %%
re = df[['channelTitle', 'channelId']].drop_duplicates().channelId.value_counts()
re = re[re > 1].shape[0]
re
# Out:
# 71

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',50)
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/nba/nba.csv",encoding='latin',sep=';')
df.head()
# Out:
#    Rk             Player Pos  Age   Tm   G  GS    MP   FG   FGA    FG%   3P  \
# 0   1   Precious Achiuwa   C   22  TOR  73  28  23.6  3.6   8.3  0.439  0.8
# 1   2       Steven Adams   C   28  MEM  76  75  26.3  2.8   5.1  0.547  0.0
# 2   3        Bam Adebayo   C   24  MIA  56  56  32.6  7.3  13.0  0.557  0.0
# 3   4       Santi Aldama  PF   21  MEM  32   0  11.3  1.7   4.1  0.402  0.2
# 4   5  LaMarcus Aldridge   C   36  BRK  47  12  22.3  5.4   9.7  0.550  0.3
#
#    3PA    3P%   2P   2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB   TRB  AST  \
# 0  2.1  0.359  2.9   6.1  0.468  0.486  1.1  1.8  0.595  2.0  4.5   6.5  1.1
# 1  0.0  0.000  2.8   5.0  0.548  0.547  1.4  2.6  0.543  4.6  5.4  10.0  3.4
# 2  0.1  0.000  7.3  12.9  0.562  0.557  4.6  6.1  0.753  2.4  7.6  10.1  3.4
# 3  1.5  0.125  1.5   2.6  0.560  0.424  0.6  1.0  0.625  1.0  1.7   2.7  0.7
# 4  1.0  0.304  5.1   8.8  0.578  0.566  1.9  2.2  0.873  1.6  3.9   5.5  0.9
#
#    STL  BLK  TOV   PF   PTS
# ...

# %% [markdown]
# 104. Tm 컬럼은 각 팀의 이름을 의미한다. TOR팀의 평균나이를 소수 4째 자리까지 구하여라

# %%
# df.info()
# df.Tm.info()
# df.Tm

# %%
tor_age = df[df.Tm == 'TOR'].Age.mean()
print(round(tor_age, 4))
print(np.round(tor_age, 4))
# Out:
# 24.8696
# 24.8696

# %% [markdown]
# 105. Pos 컬럼은 포지션을 의미한다. 전체 선수 중 최소나이대의 선수들을 필터하고 그들 중 가장 많은 포지션은 무엇인지 확인하라

# %%
df[df.index.isin(df.Player.drop_duplicates().index)].Age.sort_values() # 19
# Out:
# 552    19
# 610    19
# 267    19
# 432    19
# 253    19
#        ..
# 17     37
# 368    37
# 353    38
# 382    40
# 298    41
# Name: Age, Length: 605, dtype: int64

# %%
df[df.Age == 19].Pos.value_counts() # SG
# Out:
# Pos
# SG    9
# PF    2
# SF    1
# C     1
# Name: count, dtype: int64

# %% [markdown]
# 106. 선수들의 이름은 first_name+ 공백 + last_name으로 이루어져 있다. 가장 많은 first_name은 무엇이며 몇 회 발생하는지 확인하라

# %%
df[['FirstName', 'LastName']] = df['Player'].str.split(' ', n=1, expand=True)
df.FirstName
# Out:
# 0      Precious
# 1        Steven
# 2           Bam
# 3         Santi
# 4      LaMarcus
#          ...
# 807    Thaddeus
# 808        Trae
# 809        Omer
# 810        Cody
# 811       Ivica
# Name: FirstName, Length: 812, dtype: object

# %%
df['Player'].str.split().str[0].str.lower().value_counts().head(1)
# Out:
# Player
# justin    14
# Name: count, dtype: int64

# %% [markdown]
# 107. PTS컬럼은 경기당 평균득점수 이다. 각포지션별로 경기당 평균득점수의 평균을 구하여라

# %%
df.groupby('Pos')['PTS'].mean()
# Out:
# Pos
# C         7.690769
# C-PF     12.850000
# PF        7.737500
# PF-SF     8.500000
# PG        8.325161
# PG-SG    22.000000
# SF        7.270253
# SF-SG     8.660000
# SG        7.810553
# SG-PG     9.525000
# SG-SF     7.360000
# Name: PTS, dtype: float64

# %% [markdown]
# 109. G컬럼은 참여한 경기의 숫자이다. 각 팀별로 가장 높은 경기참여 수를 가진 선수들의 경기 참여 숫자의 평균을 구하여라

# %%
df[df.index.isin(df.groupby('Tm')['G'].idxmax())][['Player']].value_counts()
df.loc[df.groupby('Tm')['G'].idxmax()][['Player']].value_counts()
# Out:
# Player
# Aaron Gordon         1
# Herbert Jones        1
# Saddiq Bey           1
# Russell Westbrook    1
# Patty Mills          1
# Oshae Brissett       1
# Miles Bridges        1
# Mikal Bridges        1
# Malik Beasley        1
# Kevon Looney         1
# Kevin Love           1
# Kenyon Martin Jr.    1
# Keldon Johnson       1
# Jordan Clarkson      1
# Jaren Jackson Jr.    1
# Harrison Barnes      1
# Alec Burks           1
# Grant Williams       1
# Georges Niang        1
# Franz Wagner         1
# Dwight Powell        1
# Duncan Robinson      1
# Deni Avdija          1
# Delon Wright         1
# Darius Bazley        1
# Chris Boucher        1
# Buddy Hield          1
# Bobby Portis         1
# Ben McLemore         1
# Ayo Dosunmu          1
# Terance Mann         1
# Name: count, dtype: int64
# Player
# Aaron Gordon         1
# Herbert Jones        1
# Saddiq Bey           1
# Russell Westbrook    1
# Patty Mills          1
# Oshae Brissett       1
# Miles Bridges        1
# ...

# %%
df.sort_values(['Tm','G'])
df.sort_values(['Tm','G']).groupby('Tm').tail(1)
# Out:
#       Rk                    Player Pos  Age   Tm   G  GS    MP   FG   FGA  \
# 570  426            Cameron Oliver  SF   25  ATL   2   0  21.5  5.0   7.5
# 37    30                Cat Barber  PG   27  ATL   3   0   4.3  0.0   1.3
# 91    74        Chaundee Brown Jr.  SG   23  ATL   3   2  27.7  3.0   8.3
# 316  240              Malcolm Hill  SG   26  ATL   3   0  15.3  1.7   2.7
# 357  267                Wes Iwundu  SF   27  ATL   3   1  27.3  2.7   6.0
# ..   ...                       ...  ..  ...  ...  ..  ..   ...  ...   ...
# 549  407                 Raul Neto  PG   29  WAS  70  19  19.6  2.9   6.3
# 241  181            Daniel Gafford   C   23  WAS  72  53  20.1  4.0   5.7
# 108   89  Kentavious Caldwell-Pope  SG   28  WAS  77  77  30.2  4.7  10.8
# 417  308             Corey Kispert  SF   22  WAS  77  36  23.4  3.0   6.7
# 25    20               Deni Avdija  SF   21  WAS  82   8  24.2  3.0   7.1
#
#        FG%   3P  3PA    3P%   2P  2PA    2P%   eFG%   FT  FTA    FT%  ORB  \
# ...

# %% [markdown]
# 111. Tm의 값이 MIA이며 Pos는 C또는 PF인 선수의 MP값의 평균은?

# %%
# 조건에 맞는 선수 필터링
filtered = df[(df['Tm'] == 'MIA') & (df['Pos'].isin(['C', 'PF']))]

# MP 평균 계산
avg_mp = filtered['MP'].mean()

print(avg_mp)
# Out:
# 16.7875

# %% [markdown]
# 112. Age의 평균 이상인 그룹과 평균 미만인 그룹간의 G값의 평균의 차이는?

# %%
df_avg = df.Age.mean()
df_avg

df1 = df[df.Age >= df_avg]
df1.head(1)

df2 = df[df.Age <= df_avg]
df2.head(1)

df_diff = df1.G.mean() - df2.G.mean()
df_diff
# Out:
# 26.051724137931036
#    Rk        Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%   3P  3PA  \
# 1   2  Steven Adams   C   28  MEM  76  75  26.3  2.8  5.1  0.547  0.0  0.0
#
#    3P%   2P  2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB   TRB  AST  STL  \
# 1  0.0  2.8  5.0  0.548  0.547  1.4  2.6  0.543  4.6  5.4  10.0  3.4  0.9
#
#    BLK  TOV   PF  PTS FirstName LastName
# 1  0.8  1.5  2.0  6.9    Steven    Adams
#    Rk            Player Pos  Age   Tm   G  GS    MP   FG  FGA    FG%   3P  \
# 0   1  Precious Achiuwa   C   22  TOR  73  28  23.6  3.6  8.3  0.439  0.8
#
#    3PA    3P%   2P  2PA    2P%   eFG%   FT  FTA    FT%  ORB  DRB  TRB  AST  \
# 0  2.1  0.359  2.9  6.1  0.468  0.486  1.1  1.8  0.595  2.0  4.5  6.5  1.1
#
#    STL  BLK  TOV   PF  PTS FirstName LastName
# 0  0.5  0.6  1.2  2.1  9.1  Precious  Achiuwa
# 3.787674551781862

# %% [markdown]
# 113. 평균나이가 가장 젊은 팀은 어디인가

# %%
df.groupby('Tm')['Age'].mean().sort_values().index[0]
# Out:
# 'MEM'

# %% [markdown]
# 114. Pos그룹별 평균 MP값을 구하여라

# %%
df.groupby('Pos')['MP'].mean()
# Out:
# Pos
# C        16.990000
# C-PF     25.350000
# PF       17.937500
# PF-SF    27.300000
# PG       19.547742
# PG-SG    37.200000
# SF       17.514557
# SF-SG    20.340000
# SG       18.554271
# SG-PG    22.950000
# SG-SF    19.620000
# Name: MP, dtype: float64

# %% [markdown]
# # 유형 2

# %% [markdown]
# ## 서비스 이탈예측 데이터
#
# 데이터 설명 : 고객의 신상정보 데이터를 통한 회사 서비스 이탈 예측 (종속변수 : Exited)
# x_train : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv
# y_train : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv
# x_test : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv
# x_label(평가용) : https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_test.csv
# 데이터 출처 : https://www.kaggle.com/shubh0799/churn-modelling 에서 변형

# %%
import pandas as pd
#데이터 로드
x_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_train.csv")
y_train = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/y_train.csv")
x_test= pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/churnk/X_test.csv")

display(x_train.head())
display(y_train.head())
# Out:
#    CustomerId    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15799217   Zetticci          791   Germany  Female   35       7
# 1    15748986    Bischof          705   Germany    Male   42       8
# 2    15722004     Hsiung          543    France  Female   31       4
# 3    15780966  Pritchard          709    France  Female   32       2
# 4    15636731      Ts'ai          714   Germany  Female   36       1
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary
# 0   52436.20              1          1               0        161051.75
# 1  166685.92              2          1               1         55313.51
# 2  138317.94              1          0               0         61843.73
# 3       0.00              2          0               0        109681.29
# 4  101609.01              2          1               1           447.73
#    CustomerId  Exited
# 0    15799217       0
# 1    15748986       0
# 2    15722004       0
# 3    15780966       0
# ...

# %%
# x_train = x_train.drop('CustomerId', axis=1)
# x_train.shape
# x_test = x_test.drop('CustomerId', axis=1)
# x_test.shape
# y_train = y_train.drop('CustomerId', axis=1)
# y_train.shape
# Out:
# (6499, 11)
# (3501, 11)
# (6499, 1)

# %%
x_train.isnull().sum()
x_test.isnull().sum()
y_train.isnull().sum()
# Out:
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# dtype: int64
# Exited    0
# dtype: int64

# %%
x_train.shape
x_test.shape
y_train.shape
# Out:
# (6499, 11)
# (3501, 11)
# (6499, 1)

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier

# %%
# x_train = pd.get_dummies(x_train)
# x_test = pd.get_dummies(x_test)
# x_test = x_test[x_train.columns]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[233], line 3
#       1 x_train = pd.get_dummies(x_train)
#       2 x_test = pd.get_dummies(x_test)
# ----> 3 x_test = x_test[x_train.columns]
#
# File C:\Anaconda3\envs\gigabitamin\Lib\site-packages\pandas\core\frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File C:\Anaconda3\envs\gigabitamin\Lib\site-packages\pandas\core\indexes\base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
x_train.shape
x_test.shape
# Out:
# (6499, 2305)
# (3501, 1704)

# %%
drop_col = ['CustomerId','Surname']
x_train_drop = x_train.drop(columns = drop_col)
x_test_drop = x_test.drop(columns = drop_col)

# import sklearn
# print(sklearn.__all__)
# import sklearn.model_selection
# print(dir(sklearn.model_selection))

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
x_train_dummies = pd.get_dummies(x_train_drop)
y = y_train['Exited']


x_test_dummies = pd.get_dummies(x_test_drop)
# train과 컬럼 순서 동일하게 하기 (더미화 하면서 순서대로 정렬을 이미 하기 때문에 오류가 난다면 해당 컬럼이 누락된것)
x_test_dummies = x_test_dummies[x_train_dummies.columns]
# print(help(train_test_split))

# %% [markdown]
# # 유형 3

# %% [markdown]
# 제공된 데이터(bcc.csv)는 암 환자와 정상인의 리지스틴 수치에 대한 자료이며,
# 두 집단의 로그 리지스틴 값에 차이가 있는지를 검정하려고 한다.
# 소문항별로 답을 구한 후, 구한 답을 제시된 [제출 형식]에 맞춰 답안 제출 페이지에 입력하시오. (단, 모델은 절편항을 포함한다.)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/refs/heads/master/krdatacertificate/s1.csv')
df.head()
# Out:
#    Resistin  Classification
# 0   7.99585               1
# 1   4.06405               1
# 2   9.27715               1
# 3  12.76600               1
# 4  10.57635               1

# %% [markdown]
# 1-1) 두 집단의 로그 리지스틴 값의 분산에 차이가 있는지를 알아보기 위해
# F-검정을 수행할 때 검정통계량의 값을 구하여라.
# (단, 분자의 자유도가 분모의 자유도보다 크도록 하여라. 반올림하여 소수 셋째 자리까지 작성)

# %%
import numpy as np
cls_1 = df[df['Classification'] == 1]['Resistin']
cls_2 = df[df['Classification'] == 2]['Resistin']

cls_1_log = np.log(cls_1)
cls_2_log = np.log(cls_2)

cls_1_var = np.var(cls_1_log, ddof=1)
cls_2_var = np.var(cls_2_log, ddof=1)

if cls_1_var > cls_2_var:
    f_stat = cls_1_var / cls_2_var
else:
    f_stat = cls_2_var / cls_1_var
    
round_result = round(f_stat, 3)
print(round_result)
# Out:
# 1.348

# %% [markdown]
# 1-2) 두 집단의 로그 리지스틴 값에 대한 합동 분산 추정량을 구하여라.
# 반올림하여 소수 셋째 자리까지 작성

# %%
n1 = len(cls_1)
n2 = len(cls_2)

var_pooled = ((n1-1)*cls_1_var + (n2-1)*cls_2_var) / (n1+n2-2)
print(round(var_pooled, 3))
# Out:
# 0.449

# %% [markdown]
# 1-3) 2번 문제에서 구한 합동 분산 추정량을 이용하여 두 집단의 로그 리지스틴 값에 유의미한 차이가 있는지 독립표본 t-검정을 수행하고 p-값을 구하여라. (반올림하여 소수 셋째 자리까지 작성)

# %%
from scipy import stats

m1 = cls_1_log.mean()
m2 = cls_2_log.mean()

se = var_pooled*(1/n1 + 1/n2)
t_stat = (m1-m2) / np.sqrt(se)
p_v = 2*(1-stats.t.cdf(abs(t_stat), df=n1+n2-2))
print(round(p_v, 3))



print(stats.ttest_ind(cls_1_log, cls_2_log)[1])
# Out:
# 0.003
# 0.0030392269431433142
