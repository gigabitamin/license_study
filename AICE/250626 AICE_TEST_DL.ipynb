# %% [markdown]
# ## AICE 샘플 테스트 문제 종료로 그래프만 다시 복습

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df1 = pd.DataFrame([1, 2, 3])
df2 = pd.DataFrame([17, 63, 27])


plt.plot(df1, df2)
plt.xlabel('a')
plt.ylabel('b')
plt.title('c')
plt.legend('d')
plt.show()

# %% [markdown]
# 실제로는
# plt.plot(history.history['loss'], label='train')
# plt.plot(history.history['val_loss], label='valid)
#
# model.compile() 에서 loss='mse' 등을 넣어주고 fit() 에서 validation_data=[X_valid, y_valid] 를 넣어줬으므로 history에서 loss 와 val_loss 만 출력
#
# 따로 sklearn.ensemble 의 mean_squared_error 등의 성능 지표 함수를 불러와서 예측값과 실제 y_valid 를 비교해도 가능

# %% [markdown]
# y_train 과 y_train_pred 가 다른 차원일 경우 -> y_train_pred.flatten() 혹은 y_train.reshape
